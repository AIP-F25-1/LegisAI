# %%
# !pip -q install --upgrade requests beautifulsoup4 lxml tqdm python-dateutil
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.75 requires requests_mock, which is not installed.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.7.0 which is incompatible.
# conda-repo-cli 1.0.75 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.75 requires python-dateutil==2.8.2, but you have python-dateutil 2.9.0.post0 which is incompatible.
# conda-repo-cli 1.0.75 requires requests==2.31.0, but you have requests 2.32.5 which is incompatible.
# streamlit 1.40.2 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# anaconda-cloud-auth 0.1.4 requires pydantic<2.0, but you have pydantic 2.11.7 which is incompatible.

# %%
import os, re, io, json, time, zipfile, hashlib, argparse, sys
from datetime import datetime
from urllib.parse import urljoin, urlencode

import requests
from bs4 import BeautifulSoup
from dateutil import parser as dateparser
from tqdm import tqdm
from lxml import etree as ET

SESSION = requests.Session()
SESSION.headers.update({
    "User-Agent": "legal-ingestor/1.0 (+for research/educational use)",
    "Accept": "*/*",
    "Accept-Language": "en",
    "Connection": "keep-alive",
})

# %%
# ---------- utilities ----------

def ensure_dirs(*paths):
    for p in paths:
        os.makedirs(p, exist_ok=True)

def sha256(text_or_bytes):
    if isinstance(text_or_bytes, str):
        b = text_or_bytes.encode("utf-8", errors="ignore")
    else:
        b = text_or_bytes
    return hashlib.sha256(b).hexdigest()

def write_jsonl(path, records):
    ensure_dirs(os.path.dirname(path))
    with open(path, "a", encoding="utf-8") as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + "\n")

def save_file(path, content, mode="wb"):
    ensure_dirs(os.path.dirname(path))
    with open(path, mode) as f:
        f.write(content)

def normalize_whitespace(s):
    return re.sub(r"\s+\n", "\n", re.sub(r"[ \t]+", " ", s)).strip()

def section_hash(text):
    # Stable hash of normalized text for diffing
    return sha256(normalize_whitespace(text))

# %%
# ---------- Federal (Justice Laws) ----------

def find_zip_links_from_open_gov(dataset_page_url):
    """
    Scrape an Open Government dataset page to discover .zip resource URLs.
    (You can also pass direct ZIP URLs via --federal-zip)
    """
    r = SESSION.get(dataset_page_url, timeout=60)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")
    links = []
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if href.lower().endswith(".zip"):
            links.append(urljoin(dataset_page_url, href))
    # De-dup and keep order
    seen, out = set(), []
    for u in links:
        if u not in seen:
            seen.add(u)
            out.append(u)
    return out

def parse_justice_xml(xml_bytes):
    """
    Parse a single Justice Laws XML/WebXML file.
    This is tolerant: tries a few common namespaces.
    Returns normalized dict with sections.
    """
    parser = ET.XMLParser(recover=True, remove_blank_text=True)
    tree = ET.parse(io.BytesIO(xml_bytes), parser)
    root = tree.getroot()

    # Common namespaces observed on Justice WebXML/XML; fallback to '*'
    ns_candidates = [
        {"j": "http://laws-lois.justice.gc.ca"},
        {"w": "http://laws.justice.gc.ca"},
        {}  # no namespace
    ]

    def xp(path):
        for ns in ns_candidates:
            try:
                res = root.xpath(path, namespaces=ns)
                if res:
                    return res
            except ET.XPathEvalError:
                continue
        return []

# %%
def parse_justice_xml(xml_bytes):
    """
    Parse a single Justice Laws XML/WebXML file.
    Tolerant to a few common namespaces.
    Returns normalized dict with sections.
    """
    parser = ET.XMLParser(recover=True, remove_blank_text=True)
    tree = ET.parse(io.BytesIO(xml_bytes), parser)
    root = tree.getroot()

    # Common namespaces observed on Justice WebXML/XML; fallback to no-ns
    ns_candidates = [
        {"j": "http://laws-lois.justice.gc.ca"},
        {"w": "http://laws.justice.gc.ca"},
        {}  # no namespace
    ]

    def xp(path):
        for ns in ns_candidates:
            try:
                res = root.xpath(path, namespaces=ns)
                if res:
                    return res
            except ET.XPathEvalError:
                continue
        return []

    # Title
    title_nodes = xp("//j:Title/text()") or xp("//w:Title/text()") or xp("//Title/text()")
    title = title_nodes[0] if title_nodes else None

    # Citation (sometimes in ShortTitle or meta)
    citation_nodes = xp("//j:ShortTitle/text()") or xp("//w:ShortTitle/text()") or xp("//ShortTitle/text()")
    citation = citation_nodes[0] if citation_nodes else None

    # Consolidation date (varies)
    date_nodes = xp("//j:ConsolidationDate/text()") or xp("//w:ConsolidationDate/text()") or xp("//ConsolidationDate/text()")
    consolidation_date = None
    if date_nodes:
        try:
            consolidation_date = dateparser.parse(date_nodes[0]).date().isoformat()
        except Exception:
            consolidation_date = date_nodes[0]

    # Sections: gather by heading + block content heuristics
    sections = []
    sect_nodes = xp("//j:Section") or xp("//w:Section") or xp("//Section")
    if sect_nodes:
        for s in sect_nodes:
            # id/number
            sid = (s.get("id") or s.get("n") or s.findtext(".//{*}Num") or "").strip()
            heading = None
            hnode = s.find(".//{*}Heading")
            if hnode is not None:
                heading = "".join(hnode.itertext()).strip()

            # full text
            text = "".join(s.itertext())
            text = normalize_whitespace(text)
            sections.append({
                "id": sid or None,
                "heading": heading,
                "hash": section_hash(text),
            })
    else:
        # Fallback: split by top-level headings/anchors
        full_text = normalize_whitespace("".join(root.itertext()))
        chunks = re.split(r"\n(?=Section\s+\d+)", full_text)
        for i, chunk in enumerate(chunks, start=1):
            if not chunk.strip():
                continue
            sections.append({
                "id": f"s.{i}",
                "heading": None,
                "hash": section_hash(chunk),
            })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": consolidation_date,
        "sections": sections,
    }

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import zipfile, io
import os

# Adjust headers to mimic a browser (sometimes needed)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0 Safari/537.36",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
}

def find_zip_links(dataset_url):
    resp = requests.get(dataset_url, headers=HEADERS, timeout=30)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")
    links = []
    for a in soup.find_all("a", href=True):
        href = a["href"]
        if href.lower().endswith(".zip"):
            full = urljoin(dataset_url, href)
            links.append(full)
    # de-dup preserving order
    seen = set()
    out = []
    for u in links:
        if u not in seen:
            seen.add(u)
            out.append(u)
    return out

def download_and_extract(zip_url, dest_folder="downloads"):
    print("Downloading:", zip_url)
    resp = requests.get(zip_url, headers=HEADERS, timeout=120)
    resp.raise_for_status()
    z = zipfile.ZipFile(io.BytesIO(resp.content))
    os.makedirs(dest_folder, exist_ok=True)
    for name in z.namelist():
        # we only want XML files
        if name.lower().endswith(".xml"):
            data = z.read(name)
            # write file
            out_path = os.path.join(dest_folder, os.path.basename(name))
            with open(out_path, "wb") as f:
                f.write(data)
            print("Saved:", out_path)

if __name__ == "__main__":
    ds_url = "https://open.canada.ca/data/en/dataset/eb0dee21-9123-4d0d-b11d-0763fa1fb403"
    # (remove utm query parameter)
    zip_links = find_zip_links(ds_url)
    print("Discovered ZIPs:", zip_links)
    for z in zip_links:
        download_and_extract(z, dest_folder="snapshots/federal_xml")
# Out:
# Discovered ZIPs: []

# %%
import requests, zipfile, io, os

# CKAN API endpoint for this dataset
API_URL = "https://open.canada.ca/data/api/action/package_show"
DATASET_ID = "eb0dee21-9123-4d0d-b11d-0763fa1fb403"

resp = requests.get(API_URL, params={"id": DATASET_ID}, timeout=60)
resp.raise_for_status()
data = resp.json()

# Find all resource URLs that end with .zip
zip_urls = [res["url"] for res in data["result"]["resources"] if res["url"].lower().endswith(".zip")]

print("Discovered ZIPs:", zip_urls)

# Download and extract XML files
os.makedirs("federal_xml", exist_ok=True)

for url in zip_urls:
    print("Downloading:", url)
    r = requests.get(url, timeout=120)
    r.raise_for_status()
    with zipfile.ZipFile(io.BytesIO(r.content)) as z:
        for name in z.namelist():
            if name.lower().endswith(".xml"):
                out_path = os.path.join("federal_xml", os.path.basename(name))
                with open(out_path, "wb") as f:
                    f.write(z.read(name))
                print("Saved:", out_path)
# Out:
# Discovered ZIPs: []

# %%
import requests, zipfile, io, os

CKAN_API = "https://open.canada.ca/data/api/action/package_show"
DATASET_IDS = [
    "eb0dee21-9123-4d0d-b11d-0763fa1fb403",  # Consolidated Acts & Regs XML
    "2f4bb174-b2e7-4fb2-a7a1-a313507acbc6",  # WebXML dataset
]

def get_resources(dataset_id):
    resp = requests.get(CKAN_API, params={"id": dataset_id}, timeout=60)
    resp.raise_for_status()
    j = resp.json()
    return j["result"]["resources"]

def download_resource(resource, dest_folder="bulk_downloads"):
    url = resource["url"]
    name = resource.get("name") or resource.get("id")
    print("Trying resource:", name, url)
    # check for ZIP
    if url.lower().endswith(".zip"):
        r = requests.get(url, timeout=120)
        r.raise_for_status()
        with zipfile.ZipFile(io.BytesIO(r.content)) as z:
            for member in z.namelist():
                if member.lower().endswith(".xml"):
                    out_path = os.path.join(dest_folder, os.path.basename(member))
                    os.makedirs(os.path.dirname(out_path), exist_ok=True)
                    with open(out_path, "wb") as f:
                        f.write(z.read(member))
                    print("Extracted:", out_path)
    # direct xml
    elif url.lower().endswith(".xml"):
        r = requests.get(url, timeout=120)
        r.raise_for_status()
        out_path = os.path.join(dest_folder, name + ".xml")
        os.makedirs(os.path.dirname(out_path), exist_ok=True)
        with open(out_path, "wb") as f:
            f.write(r.content)
        print("Saved XML:", out_path)
    else:
        # maybe other formats (tar, gzip, etc.)
        print("Skipping unknown file type:", url)

def run():
    for ds in DATASET_IDS:
        resources = get_resources(ds)
        print("Dataset", ds, "has", len(resources), "resources")
        for res in resources:
            download_resource(res, dest_folder=f"downloads/{ds}")

if __name__ == "__main__":
    run()
# Out:
# Dataset eb0dee21-9123-4d0d-b11d-0763fa1fb403 has 3 resources
# Trying resource: Consolidated Statutes and regulations in XML https://laws-lois.justice.gc.ca/eng/XML/Legis.xml
# Saved XML: downloads/eb0dee21-9123-4d0d-b11d-0763fa1fb403/Consolidated Statutes and regulations in XML.xml
# Trying resource: Data dictionary https://laws-lois.justice.gc.ca/eng/XML/index.html
# Skipping unknown file type: https://laws-lois.justice.gc.ca/eng/XML/index.html
# Trying resource: Data dictionary https://laws-lois.justice.gc.ca/fra/XML/index.html
# Skipping unknown file type: https://laws-lois.justice.gc.ca/fra/XML/index.html
# Dataset 2f4bb174-b2e7-4fb2-a7a1-a313507acbc6 has 3 resources
# Trying resource: Consolidated federal Acts and regulations –Bulk XML (WEB) ftp://205.193.86.89/WebXML/
# Skipping unknown file type: ftp://205.193.86.89/WebXML/
# Trying resource: Data Dictionary https://laws-lois.justice.gc.ca/eng/XML/index.html
# Skipping unknown file type: https://laws-lois.justice.gc.ca/eng/XML/index.html
# Trying resource: Data Dictionary https://laws-lois.justice.gc.ca/fra/XML/index.html
# Skipping unknown file type: https://laws-lois.justice.gc.ca/fra/XML/index.html

# %%
from lxml import etree
import requests, os

LEGIS_PATH = "downloads/eb0dee21-9123-4d0d-b11d-0763fa1fb403/Consolidated Statutes and regulations in XML.xml"
tree = etree.parse(LEGIS_PATH)
root = tree.getroot()

entries = []

# Parse Acts
for act in root.findall(".//Act"):
    title = act.findtext("Title")
    number = act.findtext("OfficialNumber")
    xml_url = act.findtext("LinkToXML")
    current_to = act.findtext("CurrentToDate")
    if title and xml_url:
        entries.append({
            "type": "Act",
            "title": title.strip(),
            "official_number": number.strip() if number else None,
            "xml_url": xml_url.strip(),
            "current_to": current_to
        })

# Parse Regulations
for reg in root.findall(".//Regulation"):
    title = reg.findtext("Title")
    number = reg.findtext("OfficialNumber")
    xml_url = reg.findtext("LinkToXML")
    current_to = reg.findtext("CurrentToDate")
    if title and xml_url:
        entries.append({
            "type": "Regulation",
            "title": title.strip(),
            "official_number": number.strip() if number else None,
            "xml_url": xml_url.strip(),
            "current_to": current_to
        })

print("Total entries found:", len(entries))
print("Sample:", entries[:5])
# Out:
# Total entries found: 11510
# Sample: [{'type': 'Act', 'title': 'Access to Information Act', 'official_number': 'A-1', 'xml_url': 'http://laws-lois.justice.gc.ca/eng/XML/A-1.xml', 'current_to': '2025-09-01'}, {'type': 'Act', 'title': 'Loi sur l’accès à l’information', 'official_number': 'A-1', 'xml_url': 'http://laws-lois.justice.gc.ca/fra/XML/A-1.xml', 'current_to': '2025-09-01'}, {'type': 'Act', 'title': 'Accessible Canada Act', 'official_number': '2019, c. 10', 'xml_url': 'http://laws-lois.justice.gc.ca/eng/XML/A-0.6.xml', 'current_to': '2025-09-01'}, {'type': 'Act', 'title': 'Loi canadienne sur l’accessibilité', 'official_number': '2019, ch. 10', 'xml_url': 'http://laws-lois.justice.gc.ca/fra/XML/A-0.6.xml', 'current_to': '2025-09-01'}, {'type': 'Act', 'title': 'Addition of Lands to Reserves and Reserve Creation Act', 'official_number': '2018, c. 27, s. 675', 'xml_url': 'http://laws-lois.justice.gc.ca/eng/XML/A-1.3.xml', 'current_to': '2025-09-01'}]

# %%
import time
import os
import requests

# Path to Desktop/Canadian_Laws on Mac
save_dir = os.path.expanduser("~/Desktop/Canadian_Laws")
os.makedirs(save_dir, exist_ok=True)

print("Saving files to:", os.path.abspath(save_dir))

for e in entries:
    url = e["xml_url"]
    fname = os.path.join(save_dir, os.path.basename(url))

    if os.path.exists(fname):
        continue  # skip already downloaded

    try:
        r = requests.get(url, timeout=60)
        r.raise_for_status()
        with open(fname, "wb") as f:
            f.write(r.content)
        print("Saved:", fname)
    except Exception as ex:
        print("Failed:", url, ex)

    time.sleep(0.5)  # polite pause
# Out:
# Saving files to: /Users/nithish/Desktop/Canadian_Laws
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-0.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-49.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-2.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Z-02.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-3.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-8.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-10.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-10.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-10.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-10.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-10.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.31.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.44.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-11.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Z-01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-12.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-12.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-13.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-13.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-17.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-18.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-18.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-1.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-1.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-3.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-3.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-5.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-5.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-6.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-6.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-8.05.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-8.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-8.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-8.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-8.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.81.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.82.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.83.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.84.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.85.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.851.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.852.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.853.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.854.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.855.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.856.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.857.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.858.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.859.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8591.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8592.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8593.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8594.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8595.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.8596.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.86.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.88.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.89.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/B-9.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-0.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-0.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-0.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-44.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.68.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.45.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-2.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-4.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.19.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-5.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-14.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-8.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-8.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-22.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.001.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/W-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-0.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.85.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.87.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-30.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-0.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.66.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-1.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-3.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-4.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-5.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.42.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.45.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.48.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.85.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.94.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-7.95.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-8.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-8.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.52.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.54.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.541.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.56.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.58.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-10.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-6.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-2.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-11.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-12.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-13.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-13.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-15.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-15.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-15.21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-15.31.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-16.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Z-040.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-17.15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-17.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-17.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-17.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-18.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-18.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-18.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-18.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-19.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-19.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-21.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-21.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-21.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-22.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.05.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-23.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-24.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-24.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-25.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-27.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-27.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-27.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-27.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-27.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-27.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-28.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-28.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-28.51.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-29.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-29.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-31.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-0.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-33.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-33.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-33.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-33.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-34.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-35.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-34.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.45.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.71.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-38.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-36.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-38.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-38.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-38.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-41.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-41.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-42.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-43.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-44.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-45.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-45.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-45.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-45.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-45.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-46.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-47.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-49.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-50.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-51.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-52.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-52.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-54.011.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-0.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.57.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/W-11.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-17.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-29.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-49.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-5.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-27.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.59.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-5.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-7.88.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-9.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-20.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-38.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-11.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/V-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-1.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-2.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-2.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-3.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-3.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Z-0.98.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/W-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-3.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/D-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-0.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-0.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-0.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-0.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-0.93.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-1.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-1.45.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-1.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-1.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-3.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-4.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-4.56.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-4.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-5.401.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-5.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-5.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-6.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-6.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-9.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-12.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-13.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-13.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-14.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-15.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-16.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-18.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-19.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-21.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-22.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/E-23.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-0.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-1.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-1.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-2.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-2.27.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-3.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-5.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-5.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.33.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.35.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.38.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-33.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-33.35.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-8.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-8.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-7.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-8.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-10.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.64.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.66.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.67.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-11.73.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-12.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-27.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-27.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-28.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-29.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-29.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-29.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-29.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-30.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-30.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-30.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.46.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-31.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-32.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-2.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-2.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-3.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-3.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-3.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-5.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-5.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-7.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-7.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-11.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-11.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/F-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-11.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-11.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/G-11.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-0.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-0.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-2.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-2.71.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.76.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-3.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-5.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-5.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/H-5.67.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-2.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-2.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.31.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.51.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.52.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.54.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-3.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-7.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-5.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-6.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-7.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-7.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-7.85.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-9.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-11.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-14.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-14.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-14.85.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-16.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-17.05.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-17.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-18.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-19.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-19.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-19.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-19.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-19.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-20.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-20.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-20.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-20.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-21.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/I-21.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-0.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-0.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-0.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-0.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-2.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/J-2.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/K-0.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/K-0.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/K-0.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/K-0.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/K-6.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/K-9.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-4.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-5.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-6.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-6.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-6.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-6.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-7.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-7.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-7.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-8.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.43.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/L-12.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.47.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.54.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.58.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-0.56.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-2.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-3.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-5.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-7.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-7.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Z-0.91.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-8.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-10.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-12.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-12.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-13.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-13.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-45.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-1.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-2.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-3.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-3.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-4.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-4.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-4.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-4.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-7.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-8.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-9.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-9.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-9.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-10.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-10.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-11.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-11.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-12.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-13.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-14.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-14.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-14.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-15.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.56.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.62.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.77.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-16.85.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/W-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-20.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-22.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-22.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-22.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-23.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-23.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-23.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-23.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-24.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-24.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-26.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-26.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-27.05.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-27.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-27.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-27.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-27.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/A-16.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-27.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.75.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/N-28.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-2.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-2.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-2.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-2.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-3.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-8.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-9.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-9.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/O-9.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-0.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-0.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-4.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-4.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-4.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/M-13.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-4.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-6.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-7.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-8.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-8.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-9.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-11.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-12.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-13.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-13.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-13.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-14.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-14.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-14.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.44.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-15.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-16.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-16.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-16.81.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-16.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-17.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-19.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-19.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-19.32.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-19.45.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-19.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-24.501.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-24.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-25.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-25.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-25.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-27.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-28.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-29.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-29.71.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-29.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.65.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-31.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-32.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-33.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-33.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-33.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-33.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-34.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-35.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/P-38.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Q-0.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Q-1.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Q-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Q-1.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/Q-1.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-3.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.48.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-3.25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-3.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-4.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-5.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-5.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-5.44.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-5.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-5.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-7.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-7.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-7.36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-7.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-7.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-8.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-8.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-8.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-8.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-10.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-11.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-12.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/R-12.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-1.04.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-1.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.49.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-10.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-4.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-6.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-6.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-7.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.35.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-8.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-10.01.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-6.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-10.1.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-10.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-10.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-10.9.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-12.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-12.55.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-12.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-13.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-14.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-14.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.34.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-15.8.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-2.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-2.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-16.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-19.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-19.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-21.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-23.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-23.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-25.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/S-27.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-1.5.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-1.6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-1.7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-2.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-1.3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-3.4.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C-16.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/T-4.2.xml
# ...
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1384.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-81-568.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-81-568.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-92-631.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-92-631.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2006-298.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2006-298.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-92-210.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-92-210.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-85-122.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-85-122.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1597.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1597.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1598.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1598.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2001-109.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2001-109.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2009-264.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2009-264.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2009-197.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2009-197.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2021-268.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2021-268.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2011-203.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2011-203.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-88-400.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-88-400.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2000-100.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2000-100.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-87-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-87-7.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2008-222.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2008-222.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2010-67.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2010-67.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-54-578.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-54-578.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1601.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1601.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2012-139.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2012-139.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2014-279.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2014-279.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-84-349.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-84-349.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-93-76.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-93-76.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-84-970.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-84-970.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2010-290.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2010-290.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1604.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1604.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2005-220.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2005-220.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2016-93.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2016-93.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1605.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1605.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._992.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._992.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2007-232.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2007-232.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1607.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1607.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-95-314.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-95-314.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-92-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-92-21.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-93-327.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-93-327.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2012-152.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2012-152.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-79-108.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-79-108.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-78-609.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-78-609.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-80-76.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-80-76.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-84-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-84-26.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-87-286.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-87-286.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._122.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._122.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-88-450.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-88-450.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-96-263.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-96-263.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1609.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1609.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._123.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._123.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-81-708.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-81-708.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-78-136.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-78-136.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-84-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-84-20.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1195.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1195.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2002-142.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2002-142.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2002-154.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2002-154.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2022-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2022-10.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2011-78.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2011-78.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2008-104.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2008-104.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2019-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2019-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2024-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2024-22.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-62.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-62.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2016-29.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2016-29.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2019-29.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2019-29.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2009-104.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2009-104.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2014-109.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2014-109.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2009-103.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2009-103.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2014-39.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2014-39.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2008-103.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2008-103.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2010-83.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2010-83.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-126.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-126.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2011-92.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2011-92.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-63.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-63.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-59.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-59.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2010-84.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2010-84.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2008-102.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2008-102.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2011-111.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2011-111.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-106.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-106.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2014-37.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2014-37.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2012-25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2012-25.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2008-101.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2008-101.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2009-73.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2009-73.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2009-94.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2009-94.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2012-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2012-24.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2014-35.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2014-35.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2014-36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2014-36.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2012-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2012-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2011-93.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2011-93.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-125.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-125.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2013-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2013-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2011-58.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2011-58.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2011-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2011-14.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-93-150.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-93-150.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-98-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-98-3.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-95-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-95-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-96-87.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-96-87.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-99-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-99-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2014-38.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2014-38.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2010-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2010-18.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1530.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1530.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1533.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1533.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-92-111.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-92-111.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1535.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1535.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1537.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1537.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-92-74.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-92-74.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-91-155.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-91-155.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-92-139.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-92-139.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-92-41.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-92-41.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-92-73.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-92-73.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1539.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1539.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1540.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1540.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._1541.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._1541.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2007-69.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2007-69.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2007-80.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2007-80.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2000-143.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2000-143.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2019-151.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2019-151.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-78-830.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-78-830.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2020-130.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2020-130.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-85-154.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-85-154.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-2024-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-2024-6.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2002-259.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2002-259.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2021-62.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2021-62.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-95-507.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-95-507.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._125.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._125.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-79-276.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-79-276.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-80-167.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-80-167.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-84-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-84-23.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-81-472.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-81-472.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-87-605.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-87-605.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2013-38.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2013-38.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-2005-43.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-2005-43.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SI-93-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/TR-93-53.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_c._854.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/C.R.C.,_ch._854.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-73-71.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-73-71.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/SOR-88-427.xml
# Saved: /Users/nithish/Desktop/Canadian_Laws/DORS-88-427.xml

# %%
from lxml import etree

def parse_law_xml(path):
    tree = etree.parse(path)
    root = tree.getroot()

    # Title: look for Act/Reg Title
    title = root.findtext(".//Title")
    if not title:
        # fallback if English/French pairs exist
        title = root.findtext(".//TitleEn") or root.findtext(".//LongTitle")

    # Citation (short title or official number)
    citation = root.findtext(".//ShortTitle")
    if not citation:
        citation = root.findtext(".//OfficialNumber")

    # Consolidation date
    consolidation_date = root.findtext(".//CurrentToDate")

    sections = []
    for sec in root.findall(".//Section"):
        sid = sec.get("id") or sec.findtext(".//Label")  # try attribute or <Label>
        heading = sec.findtext(".//MarginalNote") or sec.findtext(".//Heading")
        text = " ".join(sec.itertext()).strip()
        sections.append({
            "id": sid,
            "heading": heading,
            "text": text
        })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": consolidation_date,
        "sections": sections
    }

# %%
from lxml import etree
import os, json

def parse_law_xml(path):
    tree = etree.parse(path)
    root = tree.getroot()

    title = root.findtext(".//Title")
    citation = root.findtext(".//ShortTitle") or os.path.basename(path)
    current_to = root.findtext(".//CurrentToDate")

    sections = []
    for sec in root.findall(".//Section"):
        sid = sec.get("id") or None
        heading = sec.findtext(".//MarginalNote") or sec.findtext(".//Heading")
        text = " ".join(sec.itertext()).strip()
        sections.append({
            "id": sid,
            "heading": heading,
            "text": text
        })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": current_to,
        "sections": sections
    }

# Example: parse one file
parsed = parse_law_xml("federal_laws/A-0.6.xml")
print(json.dumps(parsed, indent=2)[:800])
# Out:
# {
#   "title": null,
#   "citation": "Accessible Canada Act",
#   "consolidation_date": null,
#   "sections": [
#     {
#       "id": null,
#       "heading": "Short title",
#       "text": "Short title 1 This Act may be cited as the  Accessible Canada Act ."
#     },
#     {
#       "id": null,
#       "heading": "Definitions",
#       "text": "Definitions 2 The following definitions apply in this Act. Accessibility Commissioner \u2002means the member of the Canadian Human Rights Commission that is appointed under subsection 26(1) of the  Canadian Human Rights Act  and that is referred to in that Act as the \u201cAccessibility Commissioner\u201d.\u2002( commissaire \u00e0 l\u2019accessibilit\u00e9 ) barrier \u2002means anything \u2014 including anything physical, architectural, technological or attitudinal, anythi

# %%
from lxml import etree
import os, json

def parse_law_xml(path):
    tree = etree.parse(path)
    root = tree.getroot()

    # Title (inside Act/Regulation)
    title = root.findtext(".//Act/Title") or root.findtext(".//Regulation/Title")

    # Citation (official number, or short title)
    citation = root.findtext(".//Act/OfficialNumber") or \
               root.findtext(".//Regulation/OfficialNumber") or \
               root.findtext(".//ShortTitle")

    # Consolidation date
    consolidation_date = root.findtext(".//CurrentToDate")

    sections = []
    for sec in root.findall(".//Section"):
        sid = sec.findtext(".//Label")  # section number
        heading = sec.findtext(".//MarginalNote") or sec.findtext(".//Heading")
        text = " ".join(sec.itertext()).strip()
        sections.append({
            "id": sid,
            "heading": heading,
            "text": text
        })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": consolidation_date,
        "sections": sections
    }

# Test on one file
test_file = os.path.expanduser("~/Desktop/Canadian_Laws/A-0.6.xml")
parsed = parse_law_xml(test_file)
print(json.dumps(parsed, indent=2, ensure_ascii=False)[:1200])
# Out:
# {
#   "title": null,
#   "citation": "Accessible Canada Act",
#   "consolidation_date": null,
#   "sections": [
#     {
#       "id": "1",
#       "heading": "Short title",
#       "text": "Short title 1 This Act may be cited as the  Accessible Canada Act ."
#     },
#     {
#       "id": "2",
#       "heading": "Definitions",
#       "text": "Definitions 2 The following definitions apply in this Act. Accessibility Commissioner  means the member of the Canadian Human Rights Commission that is appointed under subsection 26(1) of the  Canadian Human Rights Act  and that is referred to in that Act as the “Accessibility Commissioner”. ( commissaire à l’accessibilité ) barrier  means anything — including anything physical, architectural, technological or attitudinal, anything that is based on information or communications or anything that is the result of a policy or a practice — that hinders the full and equal participation in society of persons with an impairment, including a physical, mental, intellectual, cognitive, learning, communication or sensory impairment or a functional limitation. ( obstacle ) broadcasting undertaking  has the same meaning as in subsection 2(1) of the  Broadcasting Act . ( entreprise

# %%
from lxml import etree
import os, json

def parse_law_xml(path):
    tree = etree.parse(path)
    root = tree.getroot()

    # Title: try multiple places (Acts and Regs may differ)
    title = (
        root.findtext(".//LongTitle") or
        root.findtext(".//ShortTitle") or
        root.findtext(".//Title")
    )

    # Citation: official number, or short title as fallback
    citation = (
        root.findtext(".//OfficialNumber") or
        root.findtext(".//ShortTitle") or
        os.path.basename(path).replace(".xml", "")
    )

    # Consolidation date (explicitly check Act or Regulation block)
    consolidation_date = (
        root.findtext(".//Act/CurrentToDate") or
        root.findtext(".//Regulation/CurrentToDate")
    )

    sections = []
    for sec in root.findall(".//Section"):
        sid = sec.findtext(".//Label")  # section number
        heading = sec.findtext(".//MarginalNote") or sec.findtext(".//Heading")
        text = " ".join(sec.itertext()).strip()
        sections.append({
            "id": sid,
            "heading": heading,
            "text": text
        })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": consolidation_date,
        "sections": sections
    }

# --- Test it on your sample XML ---
test_file = os.path.expanduser("~/Desktop/Canadian_Laws/A-0.6.xml")
parsed = parse_law_xml(test_file)

# Preview the result
print(json.dumps(parsed, indent=2, ensure_ascii=False)[:1200])
# Out:
# {
#   "title": "An Act to ensure a barrier-free Canada",
#   "citation": "Accessible Canada Act",
#   "consolidation_date": null,
#   "sections": [
#     {
#       "id": "1",
#       "heading": "Short title",
#       "text": "Short title 1 This Act may be cited as the  Accessible Canada Act ."
#     },
#     {
#       "id": "2",
#       "heading": "Definitions",
#       "text": "Definitions 2 The following definitions apply in this Act. Accessibility Commissioner  means the member of the Canadian Human Rights Commission that is appointed under subsection 26(1) of the  Canadian Human Rights Act  and that is referred to in that Act as the “Accessibility Commissioner”. ( commissaire à l’accessibilité ) barrier  means anything — including anything physical, architectural, technological or attitudinal, anything that is based on information or communications or anything that is the result of a policy or a practice — that hinders the full and equal participation in society of persons with an impairment, including a physical, mental, intellectual, cognitive, learning, communication or sensory impairment or a functional limitation. ( obstacle ) broadcasting undertaking  has the same meaning as in subsection 2(1) of

# %%
from lxml import etree
import os, json

def parse_law_xml(path):
    parser = etree.XMLParser(recover=True)
    tree = etree.parse(path, parser)
    root = tree.getroot()

    # Title
    title = (
        root.findtext(".//{*}LongTitle") or
        root.findtext(".//{*}ShortTitle") or
        root.findtext(".//{*}Title")
    )

    # Citation
    citation = (
        root.findtext(".//{*}OfficialNumber") or
        root.findtext(".//{*}ShortTitle") or
        os.path.basename(path).replace(".xml", "")
    )

    # Consolidation / date info
    consolidation_date = None
    node = root.find(".//{*}CurrentToDate")
    if node is not None:
        consolidation_date = node.text or node.attrib.get("Date")
    else:
        # fallback: check attributes on root <Statute> or <Regulation>
        consolidation_date = root.attrib.get("{http://justice.gc.ca/lims}current-date")

    # Sections
    sections = []
    for sec in root.findall(".//{*}Section"):
        sid = sec.findtext(".//{*}Label")
        heading = sec.findtext(".//{*}MarginalNote") or sec.findtext(".//{*}Heading")
        text = " ".join(sec.itertext()).strip()
        sections.append({
            "id": sid,
            "heading": heading,
            "text": text
        })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": consolidation_date,
        "inforce_start_date": root.attrib.get("{http://justice.gc.ca/lims}inforce-start-date"),
        "enacted_date": root.attrib.get("{http://justice.gc.ca/lims}enacted-date"),
        "last_amended_date": root.attrib.get("{http://justice.gc.ca/lims}lastAmendedDate"),
        "sections": sections
    }

# Test
test_file = os.path.expanduser("~/Desktop/Canadian_Laws/A-0.6.xml")
parsed = parse_law_xml(test_file)
print(json.dumps(parsed, indent=2, ensure_ascii=False)[:1200])
# Out:
# {
#   "title": "An Act to ensure a barrier-free Canada",
#   "citation": "Accessible Canada Act",
#   "consolidation_date": "2023-05-03",
#   "inforce_start_date": "2019-06-21",
#   "enacted_date": "2019-06-21",
#   "last_amended_date": "2023-04-27",
#   "sections": [
#     {
#       "id": "1",
#       "heading": "Short title",
#       "text": "Short title 1 This Act may be cited as the  Accessible Canada Act ."
#     },
#     {
#       "id": "2",
#       "heading": "Definitions",
#       "text": "Definitions 2 The following definitions apply in this Act. Accessibility Commissioner  means the member of the Canadian Human Rights Commission that is appointed under subsection 26(1) of the  Canadian Human Rights Act  and that is referred to in that Act as the “Accessibility Commissioner”. ( commissaire à l’accessibilité ) barrier  means anything — including anything physical, architectural, technological or attitudinal, anything that is based on information or communications or anything that is the result of a policy or a practice — that hinders the full and equal participation in society of persons with an impairment, including a physical, mental, intellectual, cognitive, learning, communication or sensory impairmen

# %%
import os, json
from lxml import etree
from tqdm import tqdm

folder = os.path.expanduser("~/Desktop/Canadian_Laws")
save_path = os.path.expanduser("~/Desktop/canadian_laws.jsonl")

def parse_law_xml(path):
    parser = etree.XMLParser(recover=True)
    tree = etree.parse(path, parser)
    root = tree.getroot()

    title = (
        root.findtext(".//{*}LongTitle") or
        root.findtext(".//{*}ShortTitle") or
        root.findtext(".//{*}Title")
    )

    citation = (
        root.findtext(".//{*}OfficialNumber") or
        root.findtext(".//{*}ShortTitle") or
        os.path.basename(path).replace(".xml", "")
    )

    consolidation_date = None
    node = root.find(".//{*}CurrentToDate")
    if node is not None:
        consolidation_date = node.text or node.attrib.get("Date")
    else:
        consolidation_date = root.attrib.get("{http://justice.gc.ca/lims}current-date")

    sections = []
    for sec in root.findall(".//{*}Section"):
        sid = sec.findtext(".//{*}Label")
        heading = sec.findtext(".//{*}MarginalNote") or sec.findtext(".//{*}Heading")
        text = " ".join(sec.itertext()).strip()
        sections.append({
            "id": sid,
            "heading": heading,
            "text": text
        })

    return {
        "title": title,
        "citation": citation,
        "consolidation_date": consolidation_date,
        "inforce_start_date": root.attrib.get("{http://justice.gc.ca/lims}inforce-start-date"),
        "enacted_date": root.attrib.get("{http://justice.gc.ca/lims}enacted-date"),
        "last_amended_date": root.attrib.get("{http://justice.gc.ca/lims}lastAmendedDate"),
        "sections": sections
    }

# --- Build JSONL dataset ---
with open(save_path, "w", encoding="utf-8") as f:
    for file in tqdm(os.listdir(folder)):
        if file.endswith(".xml"):
            path = os.path.join(folder, file)
            try:
                record = parse_law_xml(path)
                f.write(json.dumps(record, ensure_ascii=False) + "\n")
            except Exception as e:
                print("❌ Failed:", file, "->", e)

print("✅ Dataset saved to:", save_path)
# Out:
# 100%|██████████| 10554/10554 [00:11<00:00, 890.34it/s]
# ✅ Dataset saved to: /Users/nithish/Desktop/canadian_laws.jsonl

# %%
import os
import json
from datasets import load_dataset
import pyarrow.parquet as pq

def ingest_from_hf(save_folder="cases_hf"):
    ds = load_dataset("a2aj/canadian-case-law", split="train")
    os.makedirs(save_folder, exist_ok=True)
    for i, rec in enumerate(ds):
        # Each rec likely has fields: citation, document_date, name, unofficial_text, source_url, etc.
        fname = f"{rec['citation']}_{i}.json"
        path = os.path.join(save_folder, fname)
        with open(path, "w", encoding="utf-8") as f:
            f.write(json.dumps(rec, ensure_ascii=False))
    print("Saved from Hugging Face dataset to", save_folder)

def ingest_from_parquet(parquet_path, save_folder="cases_parquet"):
    table = pq.read_table(parquet_path)
    os.makedirs(save_folder, exist_ok=True)
    # Convert to Python dict
    df = table.to_pandas()
    for idx, row in df.iterrows():
        rec = row.to_dict()
        fname = f"{rec.get('citation','case')}_{idx}.json"
        path = os.path.join(save_folder, fname)
        with open(path, "w", encoding="utf-8") as f:
            f.write(json.dumps(rec, ensure_ascii=False))
    print("Saved from Parquet to", save_folder)

# %%
from datasets import load_dataset

# Load the dataset
ds = load_dataset("a2aj/canadian-case-law", split="train")

# Peek at the first few cases
for i in range(3):
    print(ds[i])
# Out:
# {'dataset': 'CHRT', 'citation_en': '2018 CHRT 6', 'citation2_en': '', 'name_en': 'Attaran v. Citizenship and Immigration Canada', 'document_date_en': Timestamp('2018-02-21 00:00:00+0000', tz='UTC'), 'url_en': 'https://decisions.chrt-tcdp.gc.ca/chrt-tcdp/decisions/en/item/346073/index.do', 'scraped_timestamp_en': Timestamp('2023-12-01 16:04:03.290000+0000', tz='UTC'), 'unofficial_text_en': 'Attaran v. Citizenship and Immigration Canada\nCollection\nCanadian Human Rights Tribunal\nDate\n2018-02-21\nNeutral citation\n2018 CHRT 6\nFile number(s)\nT2163/3716\nDecision-maker(s)\nThomas, David L.\nDecision type\nRuling\nGrounds\nAge\nFamily Status\nNational or Ethnic Origin\nRace\nDecision Content\nCanadian Human Rights Tribunal\nTribunal canadien des droits de la personne\nCitation: 2018CHRT\n6\nDate:\nFebruary 21, 2018\nFile No.:\nT2163/3716\nBetween:\nAmir Attaran\nComplainant\n- and -\nCanadian Human Rights Commission\nCommission\n- and -\nImmigration, Refugees and Citizenship Canada (formerly Citizenship and Immigration Canada)\nRespondent\nRuling\nMember:\nDavid L. Thomas\nTable of Contents\nI. Introduction 1\nII. The Law 2\nIII. Positions of the Parties 4\nIV. Decision 6\nI. Introduction\n[1] This is a ruling on a motion dated August 10, 2017, by the Chinese and Southeast Asian Legal Clinic (“CSALC”) which seeks interested party status in the inquiry into the complaint of Amir Attaran against Immigration, Refugees and Citizenship Canada (“IRCC”). The motion was brought under Rule 3 of the Canadian Human Rights Tribunal (the “Tribunal”) Rules of Procedure for an Order under Rule 8(1) to grant it interested party status so it could:\nA) Intervene in this case;\nB) File a statement of particulars and evidence;\nC) Make written and oral submissions at the hearing; and\nD) Call witnesses and evidence at the hearing.\n[2] CSALC proposed to narrow the scope of its participation two times after filing its motion: firstly by way of letter dated August 22, 2017 (see para. 14 herein); and, finally in its reply to the submissions of the other parties (see para. 18 herein.)\n[3] Mr. Attaran’s complaint against IRCC was filed with the Canadian Human Rights Commission (the “Commission”) on July 28, 2010. The complaint alleged that the significant delay in processing sponsorship applications for parents and grandparents, compared to other categories under the Family Class (as defined in the Regulations to the Immigration and Refugee Protection Act, S.C. 2001, c. 27), was discriminatory, contrary to section 5 of the Canadian Human Rights Act, R.S.C. 1985, c. H-6 (the “Act”).\n[4] On February 22, 2012, the Commission decided that an inquiry into the complaint was not warranted. Mr. Attaran made an application to the Federal Court for a judicial review of the Commission’s refusal to refer the complaint to the Tribunal. The Federal Court dismissed his application and Mr. Attaran then appealed to the Federal Court of Appeal (“FCA”).\n[5] On February 3, 2015, the FCA allowed the appeal and referred the complaint back to the Commission, finding that it had not adequately addressed the issue of IRCC’s bona fide justification (Attaran v. Canada (A.G.), 2015 FCA 37).\n[6] Pursuant to section 44(3)(a) of the Act, on September 6, 2016, the Commission requested the Tribunal Chairperson to institute an inquiry into Mr. Attaran’s complaint.\n[7] The parties to this matter have submitted their Statements of Particulars (SOPs) but dates for the hearing have not yet been set.\n[8] CSALC is a not-for-profit organization incorporated under the laws of Ontario. It provides free legal services to and acts as an advocacy group for non-English speaking, low-income members of the Chinese, Vietnamese, Cambodian and Laotian communities living in Ontario. CSALC is also involved in law reform and has appeared before the Parliamentary Standing Committee on Citizenship and Immigration to make submissions on various topics, including family reunification and family class sp ...
# {'dataset': 'CHRT', 'citation_en': '2003 CHRT 5', 'citation2_en': '', 'name_en': 'Bushey v. Sharma', 'document_date_en': Timestamp('2003-02-11 00:00:00+0000', tz='UTC'), 'url_en': 'https://decisions.chrt-tcdp.gc.ca/chrt-tcdp/decisions/en/item/6870/index.do', 'scraped_timestamp_en': Timestamp('2023-12-01 14:30:34.981000+0000', tz='UTC'), 'unofficial_text_en': "Bushey v. Sharma\nCollection\nCanadian Human Rights Tribunal\nDate\n2003-02-11\nNeutral citation\n2003 CHRT 5\nFile number(s)\nT722/2702\nDecision-maker(s)\nHadjis, Athanasios\nDecision type\nRuling\nDecision Content\nCanadian Human Rights Tribunal Tribunal canadien des droits de la personne\nBETWEEN:\nCONNIE BUSHEY\nComplainant\n- and -\nCANADIAN HUMAN RIGHTS COMMISSION\nCommission\n- and -\nARVIND SHARMA\nRespondent\nRULING ON DISCLOSURE\n2003 CHRT 5\n2003/02/11\nMEMBER:Athanasios D. Hadjis\n[1] This ruling concerns the issue of whether the Canadian Human Rights Commission (Commission) and the Complainant are obliged to disclose the minutes of settlement regarding two other human rights complaints.\n[2] The Complainant and the Respondent are both employed by Canada Post Corporation. In 1998, they were also members of the local executive of their union, the Union of Postal Communications Employees (UPCE), which is a component of the Public Service Alliance of Canada (PSAC). The Complainant claims that Respondent sexually harassed her on an ongoing basis, during the course of his membership on the executive. As a result of this alleged harassment, the Complainant filed human rights complaints against the Respondent, the UPCE and the PSAC.\n[3] The complaints against the unions (Commission File Nos. H48451 & H48449) were settled in December 2002. The terms of the settlement have since been approved by the Commission, pursuant to s. 48 of the Act. A settlement was not, however, reached with the Respondent, and the hearing as to the merits of the complaint against him began on January 13, 2003. A second set of hearing dates is scheduled to commence on February 17, 2003.\n[4] The Respondent has taken issue with the fact that a copy of the minutes of settlement with the unions has not been disclosed to him. Although the Respondent is not represented by legal counsel and is acting on his own behalf, I understand him to be contending that he is entitled to have this document communicated to him, in accordance with Rule 6(3) of the Tribunal's Interim Rules of Procedure. This rule, when read together with Rule 6(1)(d), obliges a party to provide to other parties, copies of all documents in its possession which are relevant to any matter in issue in the case and for which no privilege is claimed. The test for relevance for these purposes has been expressed as being whether the document in question is arguably relevant to the hearing.(1)\n[5] The Commission and the Complainant are unwilling to disclose the minutes of settlement. Instead, the Commission has informed the Respondent in writing of what the Commission identifies as a general recounting of the terms of the settlement. This summary consists of four paragraphs that are set out in point form. It purportedly reflects all the essential terms of the agreement (minus the technical language), with one significant exception: the specific monetary amounts that the unions undertook to pay the Complainant have been excluded. Together with the summary, the Respondent was provided with a copy of the letter of apology from the unions to the Complainant, which was drafted in accordance with the terms of the agreement. According to Commission counsel, a single document was drafted to reflect the settlement of both complaints. The minutes of settlement contain a clause by which the parties agree to keep the terms of the agreement confidential.\n[6] The Respondent is not satisfied with this level of disclosure and has specifically requested communication of the amounts paid by the unions to the Complainant. I should point out that I have no ...
# {'dataset': 'CHRT', 'citation_en': '2003 CHRT 46', 'citation2_en': '', 'name_en': 'Morin v. Canada (Attorney General)', 'document_date_en': Timestamp('2003-10-29 00:00:00+0000', tz='UTC'), 'url_en': 'https://decisions.chrt-tcdp.gc.ca/chrt-tcdp/decisions/en/item/7162/index.do', 'scraped_timestamp_en': Timestamp('2023-12-01 14:27:11.868000+0000', tz='UTC'), 'unofficial_text_en': "Morin v. Canada (Attorney General)\nCollection\nCanadian Human Rights Tribunal\nDate\n2003-10-29\nNeutral citation\n2003 CHRT 46\nFile number(s)\nT739/4402\nDecision-maker(s)\nHadjis, Athanasios\nDecision type\nRuling\nDecision Content\nCANADIAN HUMAN RIGHTS TRIBUNAL TRIBUNAL CANADIEN DES DROITS DE LA PERSONNE\nJEAN-LUC MORIN\nComplainant\n- and -\nCANADIAN HUMAN RIGHTS COMMISSION\nCommission\n- and -\nATTORNEY GENERAL OF CANADA\nRespondent\nRULING\nMEMBER: Athanasios D. Hadjis\n2003 CHRT 46 2003/10/29\n[1] The Complainant wishes to call upon Dr. Harish C. Jain, Professor Emeritus, Human Resources and Labour Relations at the MGD School of Business of McMaster University, to testify in the present case as an expert. The Complainant proposes to qualify Prof. Jain as an expert in the field of systemic discrimination, discrimination in the large sense and racial prejudice in the workplace, from the perspective of a social scientist.\n[2] The Respondent has taken issue with Prof. Jain's proposed qualification for the purpose of this expert testimony. In addition, the Respondent questions the relevance and necessity of this proposed evidence.\n[3] The Respondent presented its objection after Prof. Jain had completed his testimony with regard solely to the matter of his qualification as an expert. On the consent of the parties, a copy of Prof. Jain's report detailing his intended evidence was provided to me to assist in my deliberations.\n[4] An analysis regarding the admissibility of expert evidence should be conducted in accordance with the leading decision of the Supreme Court of Canada on this subject, in the case of R. v. Mohan, [1994] 2 S.C.R. 9. The Court pointed out that the admission of expert evidence depends upon the application of the following criteria:\nRelevance; Necessity in assisting the trier of fact; The absence of any exclusionary rule; A properly qualified expert.\n[5] Accordingly, the first two questions for me to consider are the following: Is the proposed evidence of Prof. Jain relevant, and if so, is it necessary in assisting the Tribunal?\n[6] On the question of relevance, the Court in Mohan noted the following, at paragraph 18:\nRelevance is a threshold requirement for the admission of expert evidence as with all other evidence. Relevance is a matter to be decided by a judge as question of law. Although prima facie admissible if so related to a fact in issue that it tends to establish it, that does not end the inquiry. This merely determines the logical relevance of the evidence. Other considerations enter into the decision as to admissibility. This further inquiry may be described as a cost benefit analysis, that is whether its value is worth what it costs. See McCormick on Evidence (3rd ed. 1984), at p. 544. Cost in this context is not used in its traditional economic sense but rather in terms of its impact on the trial process. Evidence that is otherwise logically relevant may be excluded on this basis, if its probative value is overborne by its prejudicial effect, if it involves an inordinate amount of time which is not commensurate with its value or if it is misleading in the sense that its effect on the trier of fact, particularly a jury, is out of proportion to its reliability.\n[7] On the issue of necessity, the Court in Mohan cites, at paragraph 21, from its prior decision in the case of R. v. Abbey, [1982] 2 S.C.R. 24:\nWith respect to matters calling for special knowledge, an expert in the field may draw inferences and state his opinion. An expert's function is precisely this: to provide the judge and jury with a ready-mad ...

# %%
import json
from datasets import load_dataset

# Load dataset
ds = load_dataset("a2aj/canadian-case-law", split="train")

def clean_record(rec):
    """Convert timestamps and other non-JSON types to strings."""
    cleaned = {}
    for k, v in rec.items():
        if isinstance(v, (list, dict)):
            # nested structures are already JSON-compatible
            cleaned[k] = v
        elif hasattr(v, "isoformat"):  
            # pandas/Arrow Timestamps
            cleaned[k] = v.isoformat()
        else:
            cleaned[k] = str(v) if v is not None else None
    return cleaned

# Save as JSONL
with open("canadian_caselaw.jsonl", "w", encoding="utf-8") as f:
    for rec in ds:
        cleaned = clean_record(rec)
        f.write(json.dumps(cleaned, ensure_ascii=False) + "\n")

print("✅ Saved canadian_caselaw.jsonl with", len(ds), "cases")
# Out:
# ✅ Saved canadian_caselaw.jsonl with 117352 cases

# %%
import json

path = "canadian_caselaw.jsonl"

# Read first 3 lines
with open(path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        rec = json.loads(line)
        print(json.dumps(rec, indent=2, ensure_ascii=False)[:1000])  # limit preview
        print("="*80)
        if i >= 2:
            break
# Out:
# {
#   "dataset": "CHRT",
#   "citation_en": "2018 CHRT 6",
#   "citation2_en": "",
#   "name_en": "Attaran v. Citizenship and Immigration Canada",
#   "document_date_en": "2018-02-21T00:00:00+00:00",
#   "url_en": "https://decisions.chrt-tcdp.gc.ca/chrt-tcdp/decisions/en/item/346073/index.do",
#   "scraped_timestamp_en": "2023-12-01T16:04:03.290000+00:00",
#   "unofficial_text_en": "Attaran v. Citizenship and Immigration Canada\nCollection\nCanadian Human Rights Tribunal\nDate\n2018-02-21\nNeutral citation\n2018 CHRT 6\nFile number(s)\nT2163/3716\nDecision-maker(s)\nThomas, David L.\nDecision type\nRuling\nGrounds\nAge\nFamily Status\nNational or Ethnic Origin\nRace\nDecision Content\nCanadian Human Rights Tribunal\nTribunal canadien des droits de la personne\nCitation: 2018CHRT\n6\nDate:\nFebruary 21, 2018\nFile No.:\nT2163/3716\nBetween:\nAmir Attaran\nComplainant\n- and -\nCanadian Human Rights Commission\nCommission\n- and -\nImmigration, Refugees and Citizenship Canada (formerly Citizenship and I
# ================================================================================
# {
#   "dataset": "CHRT",
#   "citation_en": "2003 CHRT 5",
#   "citation2_en": "",
#   "name_en": "Bushey v. Sharma",
#   "document_date_en": "2003-02-11T00:00:00+00:00",
#   "url_en": "https://decisions.chrt-tcdp.gc.ca/chrt-tcdp/decisions/en/item/6870/index.do",
#   "scraped_timestamp_en": "2023-12-01T14:30:34.981000+00:00",
#   "unofficial_text_en": "Bushey v. Sharma\nCollection\nCanadian Human Rights Tribunal\nDate\n2003-02-11\nNeutral citation\n2003 CHRT 5\nFile number(s)\nT722/2702\nDecision-maker(s)\nHadjis, Athanasios\nDecision type\nRuling\nDecision Content\nCanadian Human Rights Tribunal Tribunal canadien des droits de la personne\nBETWEEN:\nCONNIE BUSHEY\nComplainant\n- and -\nCANADIAN HUMAN RIGHTS COMMISSION\nCommission\n- and -\nARVIND SHARMA\nRespondent\nRULING ON DISCLOSURE\n2003 CHRT 5\n2003/02/11\nMEMBER:Athanasios D. Hadjis\n[1] This ruling concerns the issue of whether the Canadian Human Rights Commission (Commission) and the Complainant are obliged to disclose the minutes of settlem
# ================================================================================
# {
#   "dataset": "CHRT",
#   "citation_en": "2003 CHRT 46",
#   "citation2_en": "",
#   "name_en": "Morin v. Canada (Attorney General)",
#   "document_date_en": "2003-10-29T00:00:00+00:00",
#   "url_en": "https://decisions.chrt-tcdp.gc.ca/chrt-tcdp/decisions/en/item/7162/index.do",
#   "scraped_timestamp_en": "2023-12-01T14:27:11.868000+00:00",
#   "unofficial_text_en": "Morin v. Canada (Attorney General)\nCollection\nCanadian Human Rights Tribunal\nDate\n2003-10-29\nNeutral citation\n2003 CHRT 46\nFile number(s)\nT739/4402\nDecision-maker(s)\nHadjis, Athanasios\nDecision type\nRuling\nDecision Content\nCANADIAN HUMAN RIGHTS TRIBUNAL TRIBUNAL CANADIEN DES DROITS DE LA PERSONNE\nJEAN-LUC MORIN\nComplainant\n- and -\nCANADIAN HUMAN RIGHTS COMMISSION\nCommission\n- and -\nATTORNEY GENERAL OF CANADA\nRespondent\nRULING\nMEMBER: Athanasios D. Hadjis\n2003 CHRT 46 2003/10/29\n[1] The Complainant wishes to call upon Dr. Harish C. Jain, Professor Emeritus, Human Resources and Labour Relations at the MGD Schoo
# ================================================================================
